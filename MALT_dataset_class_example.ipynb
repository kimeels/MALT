# %% [markdown]
# # Example of how to use the Dataset class

# %% [markdown]
# #### Import the Dataset and Lightcurve modules from MALT

# %%
from malt import Dataset
from malt import Lightcurve
import os
# Out:
# /home/kimeel/Documents/SKA-fellowship/MALT/malt_env/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# #### The Dataset object is a collection of Lightcurve objects. All the parameters of the Dataset object can be set manually when initialising the object or preferably by using the config file, the default config file is shown below

# %%
# !cat MALT.config
# Out:
# #***********************************************************#
# #                   MALT Config File                        #
# #***********************************************************#
#
# ##---------------------------------------------------------##
# #               Parameters for interpolation                #
# [INTERPOLATOR]
# #Options: True or False
# interpolate = True
# #Must be function from interpolator.py
# interp_func = get_gp
# #Options: 'rand', 'start', or any float
# ini_t = 'rand'
# #Time in days
# obs_time = 0.3333333333333333
# #Integer
# sample_size = 100
#
#
# ##---------------------------------------------------------##
# #             Parameters for machine learning               #
# [ML]
# #Must be function from feature_extraction.py
# feat_ex_method = get_wavelet_feature
# #Must be function from machine_learning.py
# ml_method = RFclassifier
# #Must be a dictionary
# hyperparams = {"n_estimators": np.arange(70,90),"criterion": ["gini", "entropy"]}
# #Integer
# n_jobs= -1
# #Options: True or False
# pca = True
# #Integer
# n_components = 20
# #Integer
# aug_num = 100
# #float between 0 and 1
# test_split = 0.25
# #Integer
# num_of_runs = 5

# %% [markdown]
# #### All functionality of the dataset object is controlled by this config file. The user can choose whether they would like to intepolate the data or not and what intepolation function to use. If the user decides to use a different interpolation function then it should be added to the interpolator.py file. The user can also choose to use different feature extraction functions and machine learning algorithms which should be added to feature_extraction.py and machine_learning.py respectively. If a different machine learning algorithm is chosen it should either be from the sklearn package or be writting in a sklearn wrapper.

# %% [markdown]
# #### We can now initialise the MALT dataset object with parameters from config file.

# %%
dataset = Dataset(configFile='MALT.config')

# %% [markdown]
# #### Get a list of all data files

# %%
root = 'example_data/'
allfiles = []
for path, subdirs, files in os.walk(root):
    for filename in files:
        f = os.path.join(path, filename)
        allfiles.append(f)

# %% [markdown]
# #### Import files into dataset object

# %%
dataset.populate(allfiles)
# Out:
# HBox(children=(IntProgress(value=0, description='Loading lightcurves', max=49, style=ProgressStyle(description…

# %% [markdown]
# #### Now that we have populated the Dataset with Lightcurves we can check what objects we have in the dataset. If the user has chosen to use GP augmentation we can also show the number of augmented lightcurves.

# %%
dataset.types()
# Out:
# AGN         :    17
# Flare-Star  :     3
# GRB         :     4
# Kilonova    :     1
# Magnetar    :     1
# Nova        :     8
# SN          :    13
# TDE         :     2
# --------------------
# Total       :    49

# %%
dataset.types(show_aug_num=True)
# Out:
# AGN         :  1700
# Flare-Star  :   300
# GRB         :   400
# Kilonova    :   100
# Magnetar    :   100
# Nova        :   800
# SN          :  1300
# TDE         :   200
# --------------------
# Total       :  4900

# %% [markdown]
# #### We can train the ML algorithm on the objects in the dataset in one easy step. This will check all the parameters in the config file and perform the interpolation and feature extraction methods that the user has defined before training.

# %%
dataset.train()
# Out:
# HBox(children=(IntProgress(value=0, description='Interpolating lightcurves', max=49, style=ProgressStyle(descr…
# HBox(children=(IntProgress(value=0, description='Extracting features', max=49, style=ProgressStyle(description…
# HBox(children=(IntProgress(value=0, description='Stacking features', max=49, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='Stacking features', max=49, style=ProgressStyle(description_w…
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   15.1s finished
# GridSearchCV took 15.83 seconds for 40 candidate parameter settings.

# %% [markdown]
# #### The user could also choose to manually Interpolate all Lightcurves in dataset and perform feature extraction.

# %%
dataset.interpolate()
dataset.extract_features()

# %% [markdown]
# #### We can check the performance of the trained algorithm by running a diagnostic test. This will train a classifier on a subset of the whole dataset a number of times (defined by the user).

# %%
d = dataset.run_diagnostic()
# Out:
# HBox(children=(IntProgress(value=0, description='Training Classifier', max=5, style=ProgressStyle(description_…
# GridSearchCV took 6.66 seconds for 40 candidate parameter settings.
# GridSearchCV took 8.20 seconds for 40 candidate parameter settings.
# GridSearchCV took 10.26 seconds for 40 candidate parameter settings.
# GridSearchCV took 9.99 seconds for 40 candidate parameter settings.
# GridSearchCV took 9.74 seconds for 40 candidate parameter settings.

# %% [markdown]
# #### We can then plot the results of the test. This will output 3 plots showing confusion matrixies for the run with the min, max and average overall accuracies.

# %%
d.plot_results()

# %% [markdown]
# #### Now that we have a trained classifier, we can use it to classify new objects. First we will load a test file into a Lightcurve object. Because we do not know the type of this object we can see that it's type attribute is None.

# %%
new_lightcurve = Lightcurve('3C120_test')
new_lightcurve.type
# Out:
# 'None'

# %% [markdown]
# #### We can now use the trained classifier to predict class of this object.

# %%
prob, label = dataset.predict(new_lightcurve)
print(prob,label)
# Out:
# 0.9518072289156626 AGN

# %% [markdown]
# #### The full probability breakdown can also be outputed.

# %%
prob,label = dataset.predict(new_lightcurve,show_prob=True)
# Out:
# AGN         : 95.18%
# Flare-Star  : 1.20%
# GRB         : 0.00%
# Kilonova    : 0.00%
# Magnetar    : 0.00%
# Nova        : 0.01%
# SN          : 2.43%
# TDE         : 1.17%

# %% [markdown]
# #### Once the type of the new object is confirmed we can add it back into the Dataset. Once that is done the classifier will be automatically retrained using this new object.

# %%
new_agn = Lightcurve('3C120_test',obj_type='AGN')
print('Type: ',new_agn.type)
# Out:
# 'AGN'

# %%
dataset.add(new_agn)
# Out:
# HBox(children=(IntProgress(value=0, description='Interpolating lightcurves', max=50, style=ProgressStyle(descr…
# HBox(children=(IntProgress(value=0, description='Extracting features', max=50, style=ProgressStyle(description…
# HBox(children=(IntProgress(value=0, description='Stacking features', max=50, style=ProgressStyle(description_w…
# HBox(children=(IntProgress(value=0, description='Stacking features', max=50, style=ProgressStyle(description_w…
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   11.0s finished
# GridSearchCV took 11.51 seconds for 40 candidate parameter settings.

# %% [markdown]
# #### We can see that there is now one more object in the dataset.

# %%
dataset.types()
# Out:
# AGN         :    18
# Flare-Star  :     3
# GRB         :     4
# Kilonova    :     1
# Magnetar    :     1
# Nova        :     8
# SN          :    13
# TDE         :     2
# --------------------
# Total       :    50

# %% [markdown]
# #### The dataset can be saved (using pickle) and loaded from a saved file.

# %%
dataset.save('Malt_demo')
# Out:
# Saved Dataset to Malt_demo.save

# %%
reloaded_dataset = Dataset.load_from_save('Malt_demo.save')
# Out:
# Loaded Dataset to Malt_demo.save.save

# %%
prob,label = reloaded_dataset.predict(new_lightcurve,show_prob=True)
# Out:
# AGN         : 96.30%
# Flare-Star  : 0.00%
# GRB         : 0.00%
# Kilonova    : 0.00%
# Magnetar    : 0.00%
# Nova        : 3.70%
# SN          : 0.00%
# TDE         : 0.00%

# %% [markdown]
# ## Everything is logged in a file called dataset.log

# %%
cat lightcurve.log
# Out:
# 2019-08-07 18:01:21 - lightcurve_logger - INFO - Initialising Dataset with parameters from config file: MALT.config
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Sco2012.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ADLeo.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/UVCet.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004dk.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB970508.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/B0605-085.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C345.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB060418.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0954+65.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ASASSN-14li.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NGC7213.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1994I.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SSCyg.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB030329.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/1803+784.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GW170817.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1998bw.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/TPyx.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NRAO530.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2011dh.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2003L.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB110709B.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0528+134p.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C279.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C454.3.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004gq.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Swift1644.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/PKS2004-447.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1980K.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2003bg.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2008ax.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C273.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1993J.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V407Cyg.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004cc.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SGR1806-20.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/AO0235+164.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NGC4278.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/2223-052.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0458-020.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1988z.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1500Cyg.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1723Aql.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2008iz.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1974Cyg.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/RSOph.txt.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/CTA102.gpsave
# 2019-08-07 18:01:35 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/YZCmi.gpsave
# 2019-08-07 18:01:38 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve Sco2012.txt
# 2019-08-07 18:01:38 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ADLeo
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve UVCet
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004dk.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB970508.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve B0605-085
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C345
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB060418.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0954+65
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ASASSN-14li.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC7213
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1994I.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SSCyg.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB030329.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 1803+784
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GW170817.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1998bw.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve TPyx.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NRAO530
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2011dh.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003L.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB110709B.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0528+134p
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C279
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C454.3
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004gq.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve Swift1644.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve PKS2004-447.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1980K.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003bg.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008ax.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C273
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1993J.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V407Cyg.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004cc.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SGR1806-20.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve AO0235+164
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC4278.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 2223-052
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0458-020
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1988z.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1500Cyg.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1723Aql.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008iz
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1974Cyg.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve RSOph.txt
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve CTA102
# 2019-08-07 18:01:39 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve YZCmi
# 2019-08-07 18:21:44 - lightcurve_logger - INFO - Initialising Dataset with parameters from config file: MALT.config
# 2019-08-07 18:21:46 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Sco2012.txt.gpsave
# 2019-08-07 18:21:46 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ADLeo.gpsave
# 2019-08-07 18:21:46 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/UVCet.gpsave
# 2019-08-07 18:21:46 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004dk.txt.gpsave
# 2019-08-07 18:21:46 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB970508.txt.gpsave
# 2019-08-07 18:21:46 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/B0605-085.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C345.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB060418.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0954+65.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ASASSN-14li.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NGC7213.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1994I.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SSCyg.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB030329.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/1803+784.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GW170817.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1998bw.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/TPyx.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NRAO530.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2011dh.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2003L.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB110709B.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0528+134p.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C279.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C454.3.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004gq.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Swift1644.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/PKS2004-447.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1980K.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2003bg.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2008ax.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C273.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1993J.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V407Cyg.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004cc.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SGR1806-20.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/AO0235+164.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NGC4278.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/2223-052.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0458-020.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1988z.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1500Cyg.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1723Aql.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2008iz.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1974Cyg.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/RSOph.txt.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/CTA102.gpsave
# 2019-08-07 18:21:47 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/YZCmi.gpsave
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve Sco2012.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ADLeo
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve UVCet
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004dk.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB970508.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve B0605-085
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C345
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB060418.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0954+65
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ASASSN-14li.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC7213
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1994I.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SSCyg.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB030329.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 1803+784
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GW170817.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1998bw.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve TPyx.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NRAO530
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2011dh.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003L.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB110709B.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0528+134p
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C279
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C454.3
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004gq.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve Swift1644.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve PKS2004-447.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1980K.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003bg.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008ax.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C273
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1993J.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V407Cyg.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004cc.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SGR1806-20.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve AO0235+164
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC4278.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 2223-052
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0458-020
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1988z.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1500Cyg.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1723Aql.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008iz
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1974Cyg.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve RSOph.txt
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve CTA102
# 2019-08-07 18:21:48 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve YZCmi
# 2019-08-07 18:22:23 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120_test.gpsave
# 2019-08-07 18:22:23 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120_test
# 2019-08-07 18:22:27 - lightcurve_logger - INFO - 3C120_test is already interpolated
# 2019-08-07 18:22:27 - lightcurve_logger - INFO - Features have already been extracted from 3C120_test
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Sco2012.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - ADLeo is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - UVCet is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2004dk.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - GRB970508.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - B0605-085 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 3C345 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - GRB060418.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 0954+65 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - ASASSN-14li.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - NGC7213 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN1994I.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SSCyg.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - GRB030329.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 1803+784 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - GW170817.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN1998bw.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - TPyx.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - NRAO530 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2011dh.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2003L.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - GRB110709B.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 0528+134p is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 3C279 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 3C454.3 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2004gq.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 3C120 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Swift1644.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - PKS2004-447.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN1980K.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2003bg.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2008ax.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 3C273 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN1993J.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - V407Cyg.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2004cc.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SGR1806-20.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - AO0235+164 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - NGC4278.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 2223-052 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - 0458-020 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN1988z.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - V1500Cyg.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - V1723Aql.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - SN2008iz is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - V1974Cyg.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - RSOph.txt is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - CTA102 is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - YZCmi is already interpolated
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120_test.gpsave
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from Sco2012.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from ADLeo
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from UVCet
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2004dk.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from GRB970508.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from B0605-085
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 3C345
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from GRB060418.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 0954+65
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from ASASSN-14li.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from NGC7213
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN1994I.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SSCyg.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from GRB030329.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 1803+784
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from GW170817.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN1998bw.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from TPyx.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from NRAO530
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2011dh.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2003L.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from GRB110709B.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 0528+134p
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 3C279
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 3C454.3
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2004gq.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 3C120
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from Swift1644.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from PKS2004-447.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN1980K.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2003bg.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2008ax.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 3C273
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN1993J.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from V407Cyg.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2004cc.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SGR1806-20.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from AO0235+164
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from NGC4278.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 2223-052
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from 0458-020
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN1988z.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from V1500Cyg.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from V1723Aql.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from SN2008iz
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from V1974Cyg.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from RSOph.txt
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from CTA102
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Features have already been extracted from YZCmi
# 2019-08-07 18:23:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120_test
# 2019-08-07 18:25:53 - lightcurve_logger - INFO - Initialising Dataset with parameters from config file: MALT.config
# 2019-08-07 18:28:10 - lightcurve_logger - INFO - Initialising Dataset with parameters from config file: MALT.config
# 2019-08-07 22:00:04 - lightcurve_logger - INFO - Initialising Dataset with parameters from config file: MALT.config
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Sco2012.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ADLeo.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/UVCet.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004dk.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB970508.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/B0605-085.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C345.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB060418.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0954+65.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ASASSN-14li.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NGC7213.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1994I.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SSCyg.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB030329.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/1803+784.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GW170817.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1998bw.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/TPyx.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NRAO530.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2011dh.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2003L.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB110709B.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0528+134p.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C279.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C454.3.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004gq.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Swift1644.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/PKS2004-447.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1980K.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2003bg.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2008ax.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C273.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1993J.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V407Cyg.txt.gpsave
# 2019-08-07 22:00:06 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004cc.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SGR1806-20.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/AO0235+164.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NGC4278.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/2223-052.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0458-020.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1988z.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1500Cyg.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1723Aql.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2008iz.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/V1974Cyg.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/RSOph.txt.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/CTA102.gpsave
# 2019-08-07 22:00:07 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/YZCmi.gpsave
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve Sco2012.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ADLeo
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve UVCet
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004dk.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB970508.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve B0605-085
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C345
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB060418.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0954+65
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ASASSN-14li.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC7213
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1994I.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SSCyg.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB030329.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 1803+784
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GW170817.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1998bw.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve TPyx.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NRAO530
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2011dh.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003L.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB110709B.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0528+134p
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C279
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C454.3
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004gq.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve Swift1644.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve PKS2004-447.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1980K.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003bg.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008ax.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C273
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1993J.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V407Cyg.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004cc.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SGR1806-20.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve AO0235+164
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC4278.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 2223-052
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0458-020
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1988z.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1500Cyg.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1723Aql.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008iz
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1974Cyg.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve RSOph.txt
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve CTA102
# 2019-08-07 22:00:08 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve YZCmi
# 2019-08-07 22:09:29 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120_test.gpsave
# 2019-08-07 22:09:29 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120_test
# 2019-08-26 16:56:05 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120_test.gpsave
# 2019-08-26 16:56:28 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120_test
# 2019-08-26 16:56:30 - lightcurve_logger - INFO - Initialising Dataset with parameters from config file: MALT.config
# 2019-08-27 12:24:58 - lightcurve_logger - INFO - Initialising Dataset with parameters from config file: MALT.config
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Sco2012.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ADLeo.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/UVCet.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004dk.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB970508.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/B0605-085.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C345.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB060418.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0954+65.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/ASASSN-14li.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NGC7213.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1994I.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SSCyg.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB030329.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/1803+784.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GW170817.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN1998bw.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/TPyx.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/NRAO530.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2011dh.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2003L.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/GRB110709B.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/0528+134p.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C279.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C454.3.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/SN2004gq.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/Swift1644.txt.gpsave
# 2019-08-27 12:25:09 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/PKS2004-447.txt.gpsave
# ...
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ADLeo
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve UVCet
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004dk.txt
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB970508.txt
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve B0605-085
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C345
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB060418.txt
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0954+65
# 2019-08-28 12:08:43 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve ASASSN-14li.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC7213
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1994I.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SSCyg.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB030329.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 1803+784
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GW170817.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1998bw.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve TPyx.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NRAO530
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2011dh.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003L.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve GRB110709B.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0528+134p
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C279
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C454.3
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004gq.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve Swift1644.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve PKS2004-447.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1980K.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2003bg.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008ax.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C273
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1993J.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V407Cyg.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2004cc.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SGR1806-20.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve AO0235+164
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve NGC4278.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 2223-052
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 0458-020
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN1988z.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1500Cyg.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1723Aql.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve SN2008iz
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve V1974Cyg.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve RSOph.txt
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve CTA102
# 2019-08-28 12:08:44 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve YZCmi
# 2019-08-28 12:12:40 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120_test.gpsave
# 2019-08-28 12:12:40 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120_test
# 2019-08-28 12:12:53 - lightcurve_logger - INFO - 3C120_test is already interpolated
# 2019-08-28 12:12:53 - lightcurve_logger - INFO - Features have already been extracted from 3C120_test
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Sco2012.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - ADLeo is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - UVCet is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2004dk.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - GRB970508.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - B0605-085 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 3C345 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - GRB060418.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 0954+65 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - ASASSN-14li.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - NGC7213 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN1994I.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SSCyg.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - GRB030329.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 1803+784 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - GW170817.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN1998bw.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - TPyx.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - NRAO530 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2011dh.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2003L.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - GRB110709B.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 0528+134p is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 3C279 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 3C454.3 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2004gq.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 3C120 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Swift1644.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - PKS2004-447.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN1980K.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2003bg.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2008ax.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 3C273 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN1993J.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - V407Cyg.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2004cc.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SGR1806-20.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - AO0235+164 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - NGC4278.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 2223-052 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - 0458-020 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN1988z.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - V1500Cyg.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - V1723Aql.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - SN2008iz is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - V1974Cyg.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - RSOph.txt is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - CTA102 is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - YZCmi is already interpolated
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Func get_gp() used saved gp: ./saved/gps/3C120_test.gpsave
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from Sco2012.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from ADLeo
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from UVCet
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2004dk.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from GRB970508.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from B0605-085
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 3C345
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from GRB060418.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 0954+65
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from ASASSN-14li.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from NGC7213
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN1994I.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SSCyg.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from GRB030329.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 1803+784
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from GW170817.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN1998bw.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from TPyx.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from NRAO530
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2011dh.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2003L.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from GRB110709B.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 0528+134p
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 3C279
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 3C454.3
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2004gq.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 3C120
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from Swift1644.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from PKS2004-447.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN1980K.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2003bg.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2008ax.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 3C273
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN1993J.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from V407Cyg.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2004cc.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SGR1806-20.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from AO0235+164
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from NGC4278.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 2223-052
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from 0458-020
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN1988z.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from V1500Cyg.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from V1723Aql.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from SN2008iz
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from V1974Cyg.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from RSOph.txt
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from CTA102
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Features have already been extracted from YZCmi
# 2019-08-28 12:13:20 - lightcurve_logger - INFO - Func get_wavelet_feature() extracted features from lightcurve 3C120_test
# 2019-08-28 12:14:43 - lightcurve_logger - INFO - Saved Dataset to Malt_demo.save
# 2019-08-28 12:14:50 - lightcurve_logger - INFO - Loaded Dataset from Malt_demo.save.save
# 2019-08-28 12:15:08 - lightcurve_logger - INFO - 3C120_test is already interpolated
# 2019-08-28 12:15:08 - lightcurve_logger - INFO - Features have already been extracted from 3C120_test
